# %%
print("Hello World")
test = 10
print(test)

# %%
print("Hello World 2")

# %%
y = 10  + x
print(y)


╒═════════════════════════════════════════════════════════════════════════════╕

# %% [markdown]
# ╘═════════════════════════════════════════════════════════════════════════════╛
# ## this is a header
