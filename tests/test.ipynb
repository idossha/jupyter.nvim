# %%
print("Hello World")
test = 10
print(test)

# %%
print("Hello World 2")
print("Hello World 4")

# %%
print("Hello World 3")
print("Test completed successfully")

# %% [markdown]
# ## This is a markdown cell
#
# This demonstrates proper notebook format compatibility.
